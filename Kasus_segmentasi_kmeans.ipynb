# %% [markdown]
# <a href="https://colab.research.google.com/github/yandri918/belajar_machine_learning_buku_ONNO-W-Purba/blob/1April2026/Kasus_segmentasi_kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# 1. Load data
df = pd.read_csv("segmentasi_kmeans.csv")

# %%
# 2. Pilih fitur
X = df[["pendapatan_tahunan", "skor_belanja"]]

# %%
# 3. Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
print(X_scaled)
# Out:
# [[-1.29398989 -0.17944458]
#  [-1.25925191  1.49537151]
#  [-1.22451392 -1.49537151]
#  [-1.18977594  1.33586522]
#  [-0.59923022 -0.13956801]
#  [-0.56449223  1.29598864]
#  [-0.52975425 -1.49537151]
#  [-0.49501627  1.13648235]
#  [ 0.26921937  0.4585806 ]
#  [ 0.33869534  0.33895088]
#  [ 0.40817131  0.61808689]
#  [ 0.47764727  0.41870402]
#  [ 1.31135888 -0.93709948]
#  [ 1.38083485 -1.01685263]
#  [ 1.45031082 -0.85734633]
#  [ 1.51978678 -0.97697605]]

# %%
# 4. Bangun model clustering
model = KMeans(n_clusters=4, random_state=42, n_init=10)
df["cluster"] = model.fit_predict(X_scaled)

# %%
# 5. Hasil print("=== KMEANS UNTUK SEGMENTASI PELANGGAN ===")
print(df)
# Out:
#     pendapatan_tahunan  skor_belanja  cluster
# 0                   15            39        0
# 1                   16            81        2
# 2                   17             6        0
# 3                   18            77        2
# 4                   35            40        0
# 5                   36            76        2
# 6                   37             6        0
# 7                   38            72        2
# 8                   60            55        3
# 9                   62            52        3
# 10                  64            59        3
# 11                  66            54        3
# 12                  90            20        1
# 13                  92            18        1
# 14                  94            22        1
# 15                  96            19        1

# %%
print("\nCentroid (dalam skala hasil standardisasi):")
print(model.cluster_centers_)
# Out:
# Centroid (dalam skala hasil standardisasi):
# [[-0.91187207 -0.8274389 ]
#  [ 1.41557283 -0.94706862]
#  [-0.87713409  1.31592693]
#  [ 0.37343332  0.4585806 ]]
