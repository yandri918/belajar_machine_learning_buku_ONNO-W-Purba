# %% [markdown]
# <a href="https://colab.research.google.com/github/yandri918/belajar_machine_learning_buku_ONNO-W-Purba/blob/belajar_google_colab/Feature_selection_dasar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("feature_engineering_mahasiswa1.csv")

# %%
print("=== KOLOM DATASET ===")
print(df.columns.tolist())
# Out:
# === KOLOM DATASET ===
# ['id', 'nama', 'kota', 'jam_belajar', 'kehadiran', 'tugas', 'nilai', 'status_kelulusan ']

# %%
# Pilih fitur yang relevan
fitur = ["jam_belajar", "kehadiran", "tugas", "kota"]
target_regresi = "nilai"
target_klasifikasi = "status_kelulusan"

# %%
df.columns = df.columns.str.strip()
X = df[fitur]
y_reg = df[target_regresi]
y_cls = df[target_klasifikasi]

# %%
print("\n=== FITUR TERPILIH ===")
print(X.head())
# Out:
# === FITUR TERPILIH ===
#    jam_belajar  kehadiran  tugas     kota
# 0            6         82     78  Jakarta
# 1            7         85     80  Bandung
# 2            8         88     84    Depok
# 3            5         79     74  Jakarta
# 4            9         90     88  Bandung

# %%
print("\n=== TARGET REGRESI ===")
print(y_reg.head())
# Out:
# === TARGET REGRESI ===
# 0    80
# 1    84
# 2    89
# 3    76
# 4    92
# Name: nilai, dtype: int64

# %%
print("\n=== TARGET KLASIFIKASI ===")
print(y_cls.head())
# Out:
# === TARGET KLASIFIKASI ===
# 0    Lulus
# 1    Lulus
# 2    Lulus
# 3    Lulus
# 4    Lulus
# Name: status_kelulusan, dtype: object
