# %% [markdown]
# <a href="https://colab.research.google.com/github/yandri918/belajar_machine_learning_buku_ONNO-W-Purba/blob/1April2026/Bab26_langkah3_fitur_target.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("mini_project_klasifikasi_kelulusan_bersih.csv")

# %%
fitur = [ "jam_belajar", "kehadiran", "nilai_tugas", "nilai_uts", "ikut_bimbingan_encoded", "akses_internet_encoded" ]
X = df[fitur]
y = df["lulus"]

# %%
print("=== FITUR ===")
print(X.head())
# Out:
# === FITUR ===
#    jam_belajar  kehadiran  nilai_tugas  nilai_uts  ikut_bimbingan_encoded  \
# 0          2.0       70.0         60.0       58.0                       0
# 1          3.0       72.0         62.0       60.0                       0
# 2          4.0       75.0         65.0       64.0                       0
# 3          5.0       78.0         68.0       66.0                       0
# 4          6.0       80.0         72.0       71.0                       1
#
#    akses_internet_encoded
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1

# %%
print("\n=== TARGET ===")
print(y.head())
# Out:
# === TARGET ===
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: lulus, dtype: int64

# %% [markdown]
# **Bab26_langkah4_train_beberapa_model**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv("mini_project_klasifikasi_kelulusan_bersih.csv")

# %%
fitur = [ "jam_belajar", "kehadiran", "nilai_tugas", "nilai_uts", "ikut_bimbingan_encoded", "akses_internet_encoded" ]

# %%
X = df[fitur]
y = df["lulus"]

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.25, random_state=42, stratify=y )

# %%
# Scaling untuk Logistic Regression
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
models = { "LogisticRegression": LogisticRegression(), "DecisionTree": DecisionTreeClassifier(max_depth=4, random_state=42), "RandomForest": RandomForestClassifier(random_state=42) }

# %%
for nama, model in models.items():
  if nama == "LogisticRegression":
    model.fit(X_train_scaled, y_train)
  else:
    model.fit(X_train, y_train)

# %%
print("Semua model berhasil dilatih.")
# Out:
# Semua model berhasil dilatih.

# %% [markdown]
# **Bab26_langkah5_bandingkan_model**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df = pd.read_csv("mini_project_klasifikasi_kelulusan_bersih.csv")

# %%
fitur = [ "jam_belajar", "kehadiran", "nilai_tugas", "nilai_uts", "ikut_bimbingan_encoded", "akses_internet_encoded" ]

# %%
X = df[fitur]
y = df["lulus"]

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.25, random_state=42, stratify=y )

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
models = { "LogisticRegression": LogisticRegression(), "DecisionTree": DecisionTreeClassifier(max_depth=4, random_state=42), "RandomForest": RandomForestClassifier(random_state=42) }

# %%
hasil = []

# %%
for nama, model in models.items():
  if nama == "LogisticRegression":
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)
  else:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
  hasil.append({ "model": nama, "accuracy": accuracy_score(y_test, y_pred), "precision": precision_score(y_test, y_pred), "recall": recall_score(y_test, y_pred), "f1_score": f1_score(y_test, y_pred) })

# %%
hasil_df = pd.DataFrame(hasil).sort_values(by="f1_score", ascending=False)

# %%
print("=== PERBANDINGAN MODEL ===")
print(hasil_df)
# Out:
# === PERBANDINGAN MODEL ===
#                 model  accuracy  precision  recall  f1_score
# 0  LogisticRegression       1.0        1.0     1.0       1.0
# 1        DecisionTree       1.0        1.0     1.0       1.0
# 2        RandomForest       1.0        1.0     1.0       1.0

# %% [markdown]
# Berdasarkan perbandingan metrik accuracy, precision, recall, dan F1-score, model Random Forest memberikan performa paling baik secara keseluruhan pada dataset ini. Namun, bila kebutuhan utama adalah interpretabilitas dan baseline yang mudah dijelaskan, Logistic Regression tetap sangat layak dipertahankan sebagai model pembanding. Dengan demikian, untuk tujuan prediksi kelulusan yang lebih akurat pada dataset ini, Random Forest dipilih sebagai kandidat model terbaik, sementara Logistic Regression tetap penting sebagai baseline interpretatif.
