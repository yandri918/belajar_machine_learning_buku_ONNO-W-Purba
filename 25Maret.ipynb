# %% [markdown]
# <a href="https://colab.research.google.com/github/yandri918/belajar_machine_learning_buku_ONNO-W-Purba/blob/belajar_google_colab/25Maret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
nilai = pd.Series([80, 85, 90, 75], index=["Andi", "Budi", "Citra", "Dina"])

# %%
print("Series nilai:")
print(nilai)
# Out:
# Series nilai:
# Andi     80
# Budi     85
# Citra    90
# Dina     75
# dtype: int64

# %%
print("\nNilai Budi:", nilai["Budi"])
print("Rata-rata:", nilai.mean())
# Out:
# Nilai Budi: 85
# Rata-rata: 82.5

# %%
data = { "nama": ["Andi", "Budi", "Citra"],
        "umur": [20, 21, 19],
         "kota": ["Jakarta", "Bandung", "Depok"] }

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#     nama  umur     kota
# 0   Andi    20  Jakarta
# 1   Budi    21  Bandung
# 2  Citra    19    Depok

# %%
penjualan = pd.Series([120, 150, 170], index=["Jan", "Feb", "Mar"])
print("=== SERIES ===")
print(penjualan)
# Out:
# === SERIES ===
# Jan    120
# Feb    150
# Mar    170
# dtype: int64

# %%
df_penjualan = pd.DataFrame({ "bulan": ["Jan", "Feb", "Mar"], "penjualan": [120, 150, 170], "biaya": [80, 95, 110] })

# %%
print("\n=== DATAFRAME ===")
print(df_penjualan)
# Out:
# === DATAFRAME ===
#   bulan  penjualan  biaya
# 0   Jan        120     80
# 1   Feb        150     95
# 2   Mar        170    110

# %%
df = pd.read_csv("mahasiswa.csv")

# %%
df.head()
# Out:
#     nama  nilai     kota
# 0   Andi     88  Jakarta
# 1   Budi     75  Bandung
# 2  Citra     93    Depok
# 3   Dina     81  Jakarta
# 4    Eka     77  Bandung

# %%
print("Shape:", df.shape)
print("Kolom:", df.columns.tolist())
print("\nTipe data:")
print(df.dtypes)
print("\nInfo DataFrame:")
print(df.info())
# Out:
# Shape: (5, 3)
# Kolom: ['nama', 'nilai', 'kota ']
#
# Tipe data:
# nama     object
# nilai     int64
# kota     object
# dtype: object
#
# Info DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nama    5 non-null      object
#  1   nilai   5 non-null      int64
#  2   kota    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
# None

# %%
import os
os.makedirs('outputs', exist_ok=True)
df.to_csv("outputs/mahasiswa_bersih.csv", index=False)
df.to_excel("outputs/mahasiswa_bersih.xlsx", index=False)

# %%
df = pd.read_csv("mahasiswa.csv")
print(df["nama"])
print(df[["nama", "nilai"]])
# Out:
# 0     Andi
# 1     Budi
# 2    Citra
# 3     Dina
# 4      Eka
# Name: nama, dtype: object
#     nama  nilai
# 0   Andi     88
# 1   Budi     75
# 2  Citra     93
# 3   Dina     81
# 4    Eka     77

# %%
print(df.loc[0])
print(df.loc[0:2, ["nama", "nilai"]])
# Out:
# nama         Andi
# nilai          88
# kota     Jakarta
# Name: 0, dtype: object
#     nama  nilai
# 0   Andi     88
# 1   Budi     75
# 2  Citra     93

# %%
print(df.iloc[0])
print(df.iloc[0:3, 0:2])
# Out:
# nama         Andi
# nilai          88
# kota     Jakarta
# Name: 0, dtype: object
#     nama  nilai
# 0   Andi     88
# 1   Budi     75
# 2  Citra     93

# %%
nilai_tinggi = df[df["nilai"] >= 80]
print(nilai_tinggi)
# Out:
#     nama  nilai     kota
# 0   Andi     88  Jakarta
# 2  Citra     93    Depok
# 3   Dina     81  Jakarta

# %%
urut_nilai = df.sort_values(by="nilai", ascending=False)
print(urut_nilai)
# Out:
#     nama  nilai     kota
# 2  Citra     93    Depok
# 0   Andi     88  Jakarta
# 3   Dina     81  Jakarta
# 4    Eka     77  Bandung
# 1   Budi     75  Bandung

# %%
# Filter nilai >= 80
df_filter = df[df["nilai"] >= 80]
# Urutkan dari tertinggi ke terendah
df_urut = df_filter.sort_values(by="nilai", ascending=False)
print(df_urut)
# Out:
#     nama  nilai     kota
# 2  Citra     93    Depok
# 0   Andi     88  Jakarta
# 3   Dina     81  Jakarta

# %%
df = pd.DataFrame({ "kota": ["Jakarta", "Bandung", "Jakarta", "Depok", "Bandung"], "produk": ["A", "A", "B", "A", "B"], "penjualan": [100, 80, 120, 90, 110] })
print(df)
# Out:
#       kota produk  penjualan
# 0  Jakarta      A        100
# 1  Bandung      A         80
# 2  Jakarta      B        120
# 3    Depok      A         90
# 4  Bandung      B        110

# %%
group_kota = df.groupby("kota")["penjualan"].sum()
print(group_kota)
# Out:
# kota
# Bandung    190
# Depok       90
# Jakarta    220
# Name: penjualan, dtype: int64

# %%
df = pd.DataFrame({ "kota": ["Jakarta", "Bandung", "Jakarta", "Depok", "Bandung"], "nilai": [88, 75, 93, 81, 77] })
ringkasan = df.groupby("kota")["nilai"].agg(["count", "mean", "min", "max"])
print(ringkasan)
# Out:
#          count  mean  min  max
# kota
# Bandung      2  76.0   75   77
# Depok        1  81.0   81   81
# Jakarta      2  90.5   88   93

# %%
ringkasan = df.groupby("kota")["nilai"].agg(["count", "mean", "min", "max"])
print(ringkasan)
# Out:
#          count  mean  min  max
# kota
# Bandung      2  76.0   75   77
# Depok        1  81.0   81   81
# Jakarta      2  90.5   88   93

# %%
df = pd.DataFrame({ "kota": ["Jakarta", "Bandung", "Jakarta", "Depok", "Bandung"], "jurusan": ["TI", "TI", "SI", "TI", "SI"], "nilai": [88, 75, 93, 81, 77] })

# %%
hasil = df.groupby(["kota", "jurusan"])["nilai"].mean()
print(hasil)
# Out:
# kota     jurusan
# Bandung  SI         77.0
#          TI         75.0
# Depok    TI         81.0
# Jakarta  SI         93.0
#          TI         88.0
# Name: nilai, dtype: float64

# %%
df = pd.DataFrame({ "kota": ["Jakarta", "Bandung", "Jakarta", "Depok", "Bandung"], "nilai": [88, 75, 93, 81, 77] })

# %%
hasil = df.groupby("kota")["nilai"].mean().reset_index()
print(hasil)
# Out:
#       kota  nilai
# 0  Bandung   76.0
# 1    Depok   81.0
# 2  Jakarta   90.5

# %%
df_mahasiswa = pd.DataFrame({"id": [1, 2, 3], "nama": ["Andi", "Budi", "Citra"] })

# %%
df_nilai = pd.DataFrame({"id": [1, 2, 3],"nilai": [88, 75, 93] })

# %%
df_gabung = pd.merge(df_mahasiswa, df_nilai, on="id")
print(df_gabung)
# Out:
#    id   nama  nilai
# 0   1   Andi     88
# 1   2   Budi     75
# 2   3  Citra     93

# %%
import pandas as pd
df1 = pd.DataFrame({"id": [1, 2, 3],
                    "nama": ["Andi", "Budi", "Citra"] })
df2 = pd.DataFrame({"id": [2, 3, 4],"nilai": [75, 93, 85] })

# %%
print("INNER JOIN")
print(pd.merge(df1, df2, on="id", how="inner"))
# Out:
# INNER JOIN
#    id   nama  nilai
# 0   2   Budi     75
# 1   3  Citra     93

# %%
print("\nLEFT JOIN")
print(pd.merge(df1, df2, on="id", how="left"))
# Out:
# LEFT JOIN
#    id   nama  nilai
# 0   1   Andi    NaN
# 1   2   Budi   75.0
# 2   3  Citra   93.0

# %%
print("\nOUTER JOIN")
print(pd.merge(df1, df2, on="id", how="outer"))
# Out:
# OUTER JOIN
#    id   nama  nilai
# 0   1   Andi    NaN
# 1   2   Budi   75.0
# 2   3  Citra   93.0
# 3   4    NaN   85.0

# %%
df1 = pd.DataFrame({ "nama": ["Andi", "Budi", "Citra","dodi"] },
index=[1, 2, 3,4])

# %%
df2 = pd.DataFrame({ "nilai": [88, 75, 93, 76] }, index=[1, 2, 3,4])

# %%
hasil = df1.join(df2, how="inner")
print(hasil)
# Out:
#     nama  nilai
# 1   Andi     88
# 2   Budi     75
# 3  Citra     93
# 4   dodi     76

# %%
penjualan = pd.DataFrame({ "tanggal": ["2026-01-01", "2026-01-02", "2026-01-03"], "omzet": [120000, 150000, 175000] })

# %%
stok = pd.DataFrame({ "tanggal": ["2026-01-01", "2026-01-02", "2026-01-03"], "stok_akhir": [50, 45, 39] })

# %%
gabung = pd.merge(penjualan, stok, on ="tanggal")
print(gabung)
# Out:
#       tanggal   omzet  stok_akhir
# 0  2026-01-01  120000          50
# 1  2026-01-02  150000          45
# 2  2026-01-03  175000          39

# %%
df = pd.read_csv("mahasiswa.csv")

# %%
print(df.head())
print(df.tail())
# Out:
#     nama  nilai     kota
# 0   Andi     88  Jakarta
# 1   Budi     75  Bandung
# 2  Citra     93    Depok
# 3   Dina     81  Jakarta
# 4    Eka     77  Bandung
#     nama  nilai     kota
# 0   Andi     88  Jakarta
# 1   Budi     75  Bandung
# 2  Citra     93    Depok
# 3   Dina     81  Jakarta
# 4    Eka     77  Bandung

# %%
print("Jumlah baris dan kolom:", df.shape)
print("Daftar kolom:", df.columns.tolist())
# Out:
# Jumlah baris dan kolom: (5, 3)
# Daftar kolom: ['nama', 'nilai', 'kota ']

# %%
print(df.columns.to_list())
# Out:
# ['nama', 'nilai', 'kota ']

# %%
print(df.dtypes)
# Out:
# nama     object
# nilai     int64
# kota     object
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nama    5 non-null      object
#  1   nilai   5 non-null      int64
#  2   kota    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
# None

# %%
print(df.describe())
# Out:
#            nilai
# count   5.000000
# mean   82.800000
# std     7.563068
# min    75.000000
# 25%    77.000000
# 50%    81.000000
# 75%    88.000000
# max    93.000000

# %%
print(df["kota "].value_counts())
# Out:
# kota
# Jakarta     2
# Bandung     2
# Depok       1
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
df_mahasiswa = pd.DataFrame({ "id": [1, 2, 3, 4, 5], "nama": ["Andi", "Budi", "Citra", "Dina", "Eka"], "nilai": [88, 75, 93, 81, 77], "kota": ["Jakarta", "Bandung", "Depok", "Jakarta", "Bandung"] })

# %%
print(df_mahasiswa)
# Out:
#    id   nama  nilai     kota
# 0   1   Andi     88  Jakarta
# 1   2   Budi     75  Bandung
# 2   3  Citra     93    Depok
# 3   4   Dina     81  Jakarta
# 4   5    Eka     77  Bandung

# %%
print("\n2. Ringkasan cepat:")
print("Shape:", df_mahasiswa.shape)
print("Kolom:", df_mahasiswa.columns.tolist())
print("Tipe data:")
print(df_mahasiswa.dtypes)
print("\nDescribe:")
print(df_mahasiswa.describe())
# Out:
# 2. Ringkasan cepat:
# Shape: (5, 4)
# Kolom: ['id', 'nama', 'nilai', 'kota']
# Tipe data:
# id        int64
# nama     object
# nilai     int64
# kota     object
# dtype: object
#
# Describe:
#              id      nilai
# count  5.000000   5.000000
# mean   3.000000  82.800000
# std    1.581139   7.563068
# min    1.000000  75.000000
# 25%    2.000000  77.000000
# 50%    3.000000  81.000000
# 75%    4.000000  88.000000
# max    5.000000  93.000000

# %%
print("\n3. Memilih kolom nama dan nilai:")
print(df_mahasiswa[["nama", "nilai","kota"]])
# Out:
# 3. Memilih kolom nama dan nilai:
#     nama  nilai     kota
# 0   Andi     88  Jakarta
# 1   Budi     75  Bandung
# 2  Citra     93    Depok
# 3   Dina     81  Jakarta
# 4    Eka     77  Bandung

# %%
print("\n4. Filter nilai >= 80:")
df_filter = df_mahasiswa[df_mahasiswa["nilai"] >= 70]
print(df_filter)
# Out:
# 4. Filter nilai >= 80:
#    id   nama  nilai     kota
# 0   1   Andi     88  Jakarta
# 1   2   Budi     75  Bandung
# 2   3  Citra     93    Depok
# 3   4   Dina     81  Jakarta
# 4   5    Eka     77  Bandung

# %%
print("\n5. Sort nilai tertinggi ke terendah:")
df_sort = df_mahasiswa.sort_values(by="nilai", ascending=False)
print(df_sort)
# Out:
# 5. Sort nilai tertinggi ke terendah:
#    id   nama  nilai     kota
# 2   3  Citra     93    Depok
# 0   1   Andi     88  Jakarta
# 3   4   Dina     81  Jakarta
# 4   5    Eka     77  Bandung
# 1   2   Budi     75  Bandung

# %%
print("\n6. Rata-rata nilai per kota:")
group_kota = df_mahasiswa.groupby("kota")["nilai"].mean().reset_index()
print(group_kota)
# Out:
# 6. Rata-rata nilai per kota:
#       kota  nilai
# 0  Bandung   76.0
# 1    Depok   93.0
# 2  Jakarta   84.5

# %%
df_jurusan = pd.DataFrame({ "id": [1, 2, 3, 4, 5], "jurusan": ["TI", "SI", "TI", "MI", "SI"] })

# %%
print(df_jurusan)
# Out:
#    id jurusan
# 0   1      TI
# 1   2      SI
# 2   3      TI
# 3   4      MI
# 4   5      SI

# %%
print("\n8. Merge mahasiswa + jurusan:")
df_gabung = pd.merge(df_mahasiswa, df_jurusan, on="id")
print(df_gabung)
# Out:
# 8. Merge mahasiswa + jurusan:
#    id   nama  nilai     kota jurusan
# 0   1   Andi     88  Jakarta      TI
# 1   2   Budi     75  Bandung      SI
# 2   3  Citra     93    Depok      TI
# 3   4   Dina     81  Jakarta      MI
# 4   5    Eka     77  Bandung      SI

# %%
import os

# %%
import os
os.makedirs('outputs', exist_ok=True)
df_gabung.to_csv("outputs/mahasiswa_gabung.csv", index=False)
print("\nFile berhasil disimpan: outputs/mahasiswa_gabung.csv")
# Out:
# File berhasil disimpan: outputs/mahasiswa_gabung.csv

# %%
import os
os.makedirs('outputs',exist_ok=True)

# %%
df_gabung.to_csv("outputs/mahasiswa_gabunt.csv",index=False)

# %%
print("\nFile berhasil disimpan: outputs/mahasiswa_gabung.csv")
# Out:
# File berhasil disimpan: outputs/mahasiswa_gabung.csv

# %%
import pandas as pd
df =pd.read_csv("data_kotor.csv")

# %%
print("=== LIMA BARIS PERTAMA ===")
print(df.head())
# Out:
# === LIMA BARIS PERTAMA ===
#    id   nama     kota umur  pengeluaran kategori_member
# 0   1   Andi  Jakarta   20     350000.0          Silver
# 1   2   Budi  Bandung   21     420000.0            Gold
# 2   3  Citra    Depok  NaN     390000.0          Silver
# 3   4   Dina  Jakarta   22    1500000.0        Platinum
# 4   5    Eka  Bandung   20     410000.0            Gold

# %%
print("\n=== SHAPE ===")
print(df.shape)
# Out:
# === SHAPE ===
# (11, 6)

# %%
print("\n=== INFO ===")
print(df.info())
# Out:
# === INFO ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                11 non-null     int64
#  1   nama              11 non-null     object
#  2   kota              10 non-null     object
#  3   umur              10 non-null     object
#  4   pengeluaran       10 non-null     float64
#  5   kategori_member   11 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 660.0+ bytes
# None

# %%
print("\n=== TIPE DATA ===")
print(df.dtypes)
# Out:
# === TIPE DATA ===
# id                    int64
# nama                 object
# kota                 object
# umur                 object
# pengeluaran         float64
# kategori_member      object
# dtype: object

# %%
print("\n=== RINGKASAN NUMERIK ===")
print(df.describe(include="all"))
# Out:
# === RINGKASAN NUMERIK ===
#                id nama     kota umur   pengeluaran kategori_member
# count   11.000000   11       10   10  1.000000e+01               11
# unique        NaN   10        4    6           NaN                3
# top           NaN  Eka  Jakarta   20           NaN            Gold
# freq          NaN    2        4    3           NaN                5
# mean     5.454545  NaN      NaN  NaN  1.463000e+06              NaN
# std      2.876235  NaN      NaN  NaN  3.019844e+06              NaN
# min      1.000000  NaN      NaN  NaN  3.500000e+05              NaN
# 25%      3.500000  NaN      NaN  NaN  3.825000e+05              NaN
# 50%      5.000000  NaN      NaN  NaN  4.075000e+05              NaN
# 75%      7.500000  NaN      NaN  NaN  4.175000e+05              NaN
# max     10.000000  NaN      NaN  NaN  9.999999e+06              NaN

# %%
df = pd.read_csv("data_kotor.csv")

# %%
print(df.isnull().sum())
# Out:
# id                  0
# nama                0
# kota                1
# umur                1
# pengeluaran         1
# kategori_member     0
# dtype: int64

# %%
df_drop = df.dropna()
print(df_drop)
# Out:
#    id   nama      kota            umur  pengeluaran kategori_member
# 0   1   Andi   Jakarta              20     350000.0          Silver
# 1   2   Budi   Bandung              21     420000.0            Gold
# 3   4   Dina   Jakarta              22    1500000.0        Platinum
# 4   5    Eka   Bandung              20     410000.0            Gold
# 5   5    Eka   Bandung              20     410000.0            Gold
# 6   6  Fajar     Depok  dua puluh tiga     380000.0          Silver
# 8   8   Hadi  Surabaya              23     365000.0          Silver
# 9   9    Ika   Jakarta              22    9999999.0        Platinum

# %%
df["umur"] = pd.to_numeric(df["umur"], errors="coerce")

# %%
df["pengeluaran"] = pd.to_numeric(df["pengeluaran"], errors="coerce")

# %%
df["umur"] = df["umur"].fillna(df["umur"].median())

# %%
df["pengeluaran"] = df["pengeluaran"].fillna(df["pengeluaran"].median())

# %%
print(df)
# Out:
#     id   nama      kota  umur  pengeluaran kategori_member
# 0    1   Andi   Jakarta  20.0     350000.0          Silver
# 1    2   Budi   Bandung  21.0     420000.0            Gold
# 2    3  Citra     Depok  21.0     390000.0          Silver
# 3    4   Dina   Jakarta  22.0    1500000.0        Platinum
# 4    5    Eka   Bandung  20.0     410000.0            Gold
# 5    5    Eka   Bandung  20.0     410000.0            Gold
# 6    6  Fajar     Depok  21.0     380000.0          Silver
# 7    7   Gina   Jakarta  24.0     407500.0            Gold
# 8    8   Hadi  Surabaya  23.0     365000.0          Silver
# 9    9    Ika   Jakarta  22.0    9999999.0        Platinum
# 10  10   Joko       NaN  21.0     405000.0            Gold

# %%
df["kota"] = df["kota"].fillna(df["kota"].mode()[0])
print(df["kota"])
# Out:
# 0      Jakarta
# 1      Bandung
# 2        Depok
# 3      Jakarta
# 4      Bandung
# 5      Bandung
# 6        Depok
# 7      Jakarta
# 8     Surabaya
# 9      Jakarta
# 10     Jakarta
# Name: kota, dtype: object

# %%
from sklearn.impute import SimpleImputer

# %%
df["umur"] = pd.to_numeric(df["umur"], errors="coerce")

# %%
df["pengeluaran"] = pd.to_numeric(df["pengeluaran"], errors="coerce")

# %%
imputer = SimpleImputer(strategy="median")

# %%
df[["umur", "pengeluaran"]] = imputer.fit_transform(df[["umur", "pengeluaran"]])

# %%
print(df)
# Out:
#     id   nama      kota  umur  pengeluaran kategori_member
# 0    1   Andi   Jakarta  20.0     350000.0          Silver
# 1    2   Budi   Bandung  21.0     420000.0            Gold
# 2    3  Citra     Depok  21.0     390000.0          Silver
# 3    4   Dina   Jakarta  22.0    1500000.0        Platinum
# 4    5    Eka   Bandung  20.0     410000.0            Gold
# 5    5    Eka   Bandung  20.0     410000.0            Gold
# 6    6  Fajar     Depok  21.0     380000.0          Silver
# 7    7   Gina   Jakarta  24.0     407500.0            Gold
# 8    8   Hadi  Surabaya  23.0     365000.0          Silver
# 9    9    Ika   Jakarta  22.0    9999999.0        Platinum
# 10  10   Joko   Jakarta  21.0     405000.0            Gold

# %%
df = pd.read_csv("data_kotor.csv")

# %%
print("Jumlah duplikat:", df.duplicated().sum())
# Out:
# Jumlah duplikat: 1

# %%
df = df.drop_duplicates()

# %%
print("Jumlah baris setelah hapus duplikat:", len(df))
# Out:
# Jumlah baris setelah hapus duplikat: 10

# %%
duplikat_id = df[df.duplicated(subset=["id"], keep=False)]
print(duplikat_id)
# Out:
# Empty DataFrame
# Columns: [id, nama, kota, umur, pengeluaran, kategori_member ]
# Index: []

# %%
df = pd.read_csv("data_kotor.csv")
print(df.dtypes)
# Out:
# id                    int64
# nama                 object
# kota                 object
# umur                 object
# pengeluaran         float64
# kategori_member      object
# dtype: object

# %%
df["umur"] = pd.to_numeric(df["umur"], errors="coerce")
df["pengeluaran"] = pd.to_numeric(df["pengeluaran"], errors="coerce")

# %%
print(df.dtypes)
print(df)
# Out:
# id                    int64
# nama                 object
# kota                 object
# umur                float64
# pengeluaran         float64
# kategori_member      object
# dtype: object
#     id   nama      kota  umur  pengeluaran kategori_member
# 0    1   Andi   Jakarta  20.0     350000.0          Silver
# 1    2   Budi   Bandung  21.0     420000.0            Gold
# 2    3  Citra     Depok   NaN     390000.0          Silver
# 3    4   Dina   Jakarta  22.0    1500000.0        Platinum
# 4    5    Eka   Bandung  20.0     410000.0            Gold
# 5    5    Eka   Bandung  20.0     410000.0            Gold
# 6    6  Fajar     Depok   NaN     380000.0          Silver
# 7    7   Gina   Jakarta  24.0          NaN            Gold
# 8    8   Hadi  Surabaya  23.0     365000.0          Silver
# 9    9    Ika   Jakarta  22.0    9999999.0        Platinum
# 10  10   Joko       NaN  21.0     405000.0            Gold

# %%
df["pengeluaran"] = pd.to_numeric(df["pengeluaran"], errors="coerce")

# %%
Q1 = df["pengeluaran"].quantile(0.25)
Q3 = df["pengeluaran"].quantile(0.75)
IQR = Q3 - Q1

# %%
batas_bawah = Q1 - 1.5 * IQR
batas_atas = Q3 + 1.5 * IQR

# %%
outlier = df[(df["pengeluaran"] < batas_bawah) | (df["pengeluaran"] > batas_atas)]

# %%
print("Batas bawah:", batas_bawah)
print("Batas atas :", batas_atas)
# Out:
# Batas bawah: 330000.0
# Batas atas : 470000.0

# %%
print("\nData outlier:")
print(outlier)
# Out:
# Data outlier:
#    id  nama     kota  umur  pengeluaran kategori_member
# 3   4  Dina  Jakarta  22.0    1500000.0        Platinum
# 9   9   Ika  Jakarta  22.0    9999999.0        Platinum

# %%
df = pd.read_csv("data_kotor.csv")

# %%
df["pengeluaran"] = pd.to_numeric(df["pengeluaran"], errors="coerce")

# %%
mean_val = df["pengeluaran"].mean()

# %%
std_val = df["pengeluaran"].std()

# %%
df["z_score"] = (df["pengeluaran"] - mean_val) / std_val

# %%
outlier = df[df["z_score"].abs() > 3]

# %%
print(outlier)
# Out:
# Empty DataFrame
# Columns: [id, nama, kota, umur, pengeluaran, kategori_member , z_score]
# Index: []

# %%
outlier = df[df["z_score"].abs() > 3]
print(outlier)
# Out:
# Empty DataFrame
# Columns: [id, nama, kota, umur, pengeluaran, kategori_member , z_score]
# Index: []

# %%
df = pd.read_csv("data_kotor.csv")
df["pengeluaran"] = pd.to_numeric(df["pengeluaran"], errors="coerce")
Q1 = df["pengeluaran"].quantile(0.25)
Q3 = df["pengeluaran"].quantile(0.75)
IQR = Q3 - Q1

# %%
batas_bawah = Q1 - 1.5 * IQR
batas_atas = Q3 + 1.5 * IQR

# %%
median_pengeluaran = df["pengeluaran"].median()

# %%
df.loc[df["pengeluaran"] > batas_atas, "pengeluaran"] = median_pengeluaran

# %%
df.loc[df["pengeluaran"] < batas_bawah, "pengeluaran"] = median_pengeluaran
print(df)
# Out:
#     id   nama      kota            umur  pengeluaran kategori_member
# 0    1   Andi   Jakarta              20     350000.0          Silver
# 1    2   Budi   Bandung              21     420000.0            Gold
# 2    3  Citra     Depok             NaN     390000.0          Silver
# 3    4   Dina   Jakarta              22     407500.0        Platinum
# 4    5    Eka   Bandung              20     410000.0            Gold
# 5    5    Eka   Bandung              20     410000.0            Gold
# 6    6  Fajar     Depok  dua puluh tiga     380000.0          Silver
# 7    7   Gina   Jakarta              24          NaN            Gold
# 8    8   Hadi  Surabaya              23     365000.0          Silver
# 9    9    Ika   Jakarta              22     407500.0        Platinum
# 10  10   Joko       NaN              21     405000.0            Gold

# %%
df = pd.read_csv("data_kotor.csv")
encoded = pd.get_dummies(df, columns=["kategori_member "], dtype=int)
print(encoded.head())
# Out:
#    id   nama     kota umur  pengeluaran  kategori_member _Gold   \
# 0   1   Andi  Jakarta   20     350000.0                       0
# 1   2   Budi  Bandung   21     420000.0                       1
# 2   3  Citra    Depok  NaN     390000.0                       0
# 3   4   Dina  Jakarta   22    1500000.0                       0
# 4   5    Eka  Bandung   20     410000.0                       1
#
#    kategori_member _Platinum   kategori_member _Silver
# 0                           0                         1
# 1                           0                         0
# 2                           0                         1
# 3                           1                         0
# 4                           0                         0

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.DataFrame({ "warna": ["Merah", "Biru", "Hijau"] })

# %%
encoder = OneHotEncoder(sparse_output=False)

# %%
hasil = encoder.fit_transform(df[["warna"]])

# %%
print(hasil)
# Out:
# [[0. 0. 1.]
#  [1. 0. 0.]
#  [0. 1. 0.]]

# %%
import pandas as pd
df = pd.DataFrame({ "prioritas": ["Rendah", "Sedang", "Tinggi", "Sedang"] })

# %%
mapping = { "Rendah": 1, "Sedang": 2, "Tinggi": 3 }

# %%
df["prioritas_encoded"] = df["prioritas"].map(mapping)
print(df)
# Out:
#   prioritas  prioritas_encoded
# 0    Rendah                  1
# 1    Sedang                  2
# 2    Tinggi                  3
# 3    Sedang                  2

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("data_kotor.csv")

# %%
df["umur"] = pd.to_numeric(df["umur"], errors="coerce")
df["pengeluaran"] = pd.to_numeric(df["pengeluaran"], errors="coerce")

# %%
df["umur"] = df["umur"].fillna(df["umur"].median())

# %%
df["pengeluaran"] = df["pengeluaran"].fillna(df["pengeluaran"].median())

# %%
scaler = MinMaxScaler()

# %%
df[["umur_normal", "pengeluaran_normal"]] = scaler.fit_transform(df[["umur", "pengeluaran"]])

# %%
print(df[["umur", "umur_normal", "pengeluaran", "pengeluaran_normal"]])
# Out:
#     umur  umur_normal  pengeluaran  pengeluaran_normal
# 0   20.0         0.00     350000.0            0.000000
# 1   21.0         0.25     420000.0            0.007254
# 2   21.0         0.25     390000.0            0.004145
# 3   22.0         0.50    1500000.0            0.119171
# 4   20.0         0.00     410000.0            0.006218
# 5   20.0         0.00     410000.0            0.006218
# 6   21.0         0.25     380000.0            0.003109
# 7   24.0         1.00     407500.0            0.005959
# 8   23.0         0.75     365000.0            0.001554
# 9   22.0         0.50    9999999.0            1.000000
# 10  21.0         0.25     405000.0            0.005699

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
df = pd.read_csv("data_kotor.csv")

# %%
df["umur"] = pd.to_numeric(df["umur"], errors="coerce")
df["pengeluaran"] = pd.to_numeric(df["pengeluaran"], errors="coerce")

# %%
df["umur"] = df["umur"].fillna(df["umur"].median())
df["pengeluaran"] = df["pengeluaran"].fillna(df["pengeluaran"].median())

# %%
scaler = StandardScaler()
df[["umur_std", "pengeluaran_std"]] = scaler.fit_transform(df[["umur", "pengeluaran"]])

# %%
print(df[["umur", "umur_std", "pengeluaran", "pengeluaran_std"]])
# Out:
#     umur  umur_std  pengeluaran  pengeluaran_std
# 0   20.0 -1.111874     350000.0        -0.370056
# 1   21.0 -0.296500     420000.0        -0.344586
# 2   21.0 -0.296500     390000.0        -0.355502
# 3   22.0  0.518875    1500000.0         0.048376
# 4   20.0 -1.111874     410000.0        -0.348225
# 5   20.0 -1.111874     410000.0        -0.348225
# 6   21.0 -0.296500     380000.0        -0.359141
# 7   24.0  2.149623     407500.0        -0.349135
# 8   23.0  1.334249     365000.0        -0.364598
# 9   22.0  0.518875    9999999.0         3.141136
# 10  21.0 -0.296500     405000.0        -0.350044

# %%
import pandas as pd
df = pd.read_csv("penjualan_visual.csv")

# %%
print(df)
# Out:
#    bulan  penjualan  biaya  produk_terjual kategori  iklan
# 0    Jan        120     80              30        A      10
# 1    Feb        135     90              34        A      12
# 2    Mar        128     85              31        B      11
# 3    Apr        150     95              36        B      14
# 4    Mei        170    110              40        A      16
# 5    Jun        165    108              39        C      15
# 6    Jul        180    120              43        C      18
# 7    Agu        175    118              42        B      17
# 8    Sep        160    105              38        A      14
# 9    Okt        190    125              45        C      19
# 10   Nov        200    130              47        B      20
# 11   Des        210    138              50        A      22

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df, x="bulan", y="penjualan", marker="o")
# Out:
# <Axes: xlabel='bulan', ylabel='penjualan'>

# %%
plt.title("Tren Penjualan Bulanan")
plt.xlabel("Bulan")
plt.ylabel("Penjualan")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.title("Tren Penjualan Bulanan")
plt.xlabel("Bulan")
plt.ylabel("Penjualan")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("penjualan_visual.csv")

# %%
# Ringkas total penjualan per kategori
df_kategori = df.groupby("kategori")["penjualan"].sum().reset_index()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_kategori, x="kategori", y="penjualan")
plt.title("Total Penjualan per Kategori")
plt.xlabel("Kategori")
plt.ylabel("Total Penjualan")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("penjualan_visual.csv")

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["penjualan"], bins=6, kde=False)
plt.title("Histogram Penjualan")
plt.xlabel("Penjualan")
plt.ylabel("Frekuensi")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["penjualan"], bins=6, kde=True)
plt.title("Histogram dan KDE Penjualan")
plt.xlabel("Penjualan")
plt.ylabel("Frekuensi / Kepadatan")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=df["penjualan"])
plt.title("Boxplot Penjualan")
plt.ylabel("Penjualan")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="kategori", y="penjualan")
plt.title("Boxplot Penjualan per Kategori")
plt.xlabel("Kategori")
plt.ylabel("Penjualan")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="iklan ", y="penjualan", hue="kategori", s=100)
plt.title("Hubungan Iklan dan Penjualan")
plt.xlabel("Biaya Iklan")
plt.ylabel("Penjualan")
plt.tight_layout()
plt.show()

# %%
df_numerik = df[["penjualan","biaya","produk_terjual","iklan "]]

# %%
corr_matrix = df_numerik.corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Heatmap Korelasi")
plt.tight_layout()
plt.show()
