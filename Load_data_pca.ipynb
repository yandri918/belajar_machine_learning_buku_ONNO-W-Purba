# %% [markdown]
# <a href="https://colab.research.google.com/github/yandri918/belajar_machine_learning_buku_ONNO-W-Purba/blob/1April2026/Load_data_pca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("pca_data_sederhana.csv", sep=',')

# %%
print("=== DATA AWAL ===")
print(df.head())
# Out:
# === DATA AWAL ===
#     f1   f2   f3   f4   f5
# 0  2.5  2.4  1.2  3.1  0.9
# 1  0.5  0.7  1.0  1.5  0.4
# 2  2.2  2.9  1.4  3.0  0.8
# 3  1.9  2.2  1.3  2.7  0.7
# 4  3.1  3.0  1.8  3.6  1.1

# %%
print("\nShape:", df.shape)
print("\nDeskripsi statistik:")
print(df.describe())
# Out:
# Shape: (15, 5)
#
# Deskripsi statistik:
#               f1         f2         f3         f4         f5
# count  15.000000  15.000000  15.000000  15.000000  15.000000
# mean    1.920000   2.020000   1.273333   2.626667   0.740000
# std     0.834266   0.926745   0.391821   0.837058   0.284856
# min     0.500000   0.600000   0.700000   1.400000   0.300000
# 25%     1.250000   1.300000   1.000000   1.900000   0.550000
# 50%     2.000000   2.200000   1.200000   2.700000   0.700000
# 75%     2.600000   2.850000   1.600000   3.300000   0.950000
# max     3.100000   3.200000   1.900000   3.800000   1.200000

# %% [markdown]
# **scaling_sebelum_pca**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("pca_data_sederhana.csv")

# %%
X = df[["f1", "f2", "f3", "f4", "f5"]]
print(X)
# Out:
#      f1   f2   f3   f4   f5
# 0   2.5  2.4  1.2  3.1  0.9
# 1   0.5  0.7  1.0  1.5  0.4
# 2   2.2  2.9  1.4  3.0  0.8
# 3   1.9  2.2  1.3  2.7  0.7
# 4   3.1  3.0  1.8  3.6  1.1
# 5   2.3  2.7  1.5  3.2  0.9
# 6   2.0  1.6  1.1  2.4  0.6
# 7   1.0  1.1  0.9  1.8  0.5
# 8   1.5  1.6  1.0  2.0  0.6
# 9   1.1  0.9  0.8  1.7  0.4
# 10  3.0  3.2  1.9  3.8  1.2
# 11  2.7  2.8  1.7  3.4  1.0
# 12  1.4  1.5  1.0  2.1  0.6
# 13  0.8  0.6  0.7  1.4  0.3
# 14  2.8  3.1  1.8  3.7  1.1

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
print("=== DATA SETELAH SCALING ===")
print(X_scaled[:5])
# Out:
# === DATA SETELAH SCALING ===
# [[ 0.71962292  0.4244287  -0.19372924  0.58531947  0.5814019 ]
#  [-1.76183542 -1.47433127 -0.7220817  -1.39322522 -1.23547904]
#  [ 0.34740417  0.98288751  0.33462323  0.46166043  0.21802571]
#  [-0.02481458  0.20104517  0.070447    0.0906833  -0.14535047]
#  [ 1.46406042  1.09457928  1.39132816  1.20361469  1.30815427]]

# %% [markdown]
# **pca_2d**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# 1. Load data
df = pd.read_csv("pca_data_sederhana.csv")

# %%
# 2. Ambil fitur
X = df[["f1", "f2", "f3", "f4", "f5"]]

# %%
# 3. Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# 4. PCA ke 2 dimensi

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
# 5. Ubah ke DataFrame
df_pca = pd.DataFrame(X_pca, columns=["PC1", "PC2"])

# %%
print("=== HASIL PCA 2D ===")
print(df_pca.head())
# Out:
# === HASIL PCA 2D ===
#         PC1       PC2
# 0  0.951323 -0.656365
# 1 -2.948374  0.755375
# 2  1.048849 -0.129407
# 3  0.085539  0.015329
# 4  2.888036  0.027958

# %%
print("\nExplained variance ratio:")
print(pca.explained_variance_ratio_)
# Out:
# Explained variance ratio:
# [0.96886808 0.01812076]
